# %% [markdown]
# # Motivation and problem statement

# %% [markdown]
# As the world is growing, changing, and getting more dynamic—it is natural for a larger number of people to feel anxious and depressed. I’m doing this analysis because talking about anxiety and depression and its side effects is close to my heart as I’ve suffered from it during the covid years, with some unexpected side effects. I’m not an expert by any means, I just know how incredibly hard having your brain not work as you want it to, can be.

# %% [markdown]
# Experts attributed the growth in adolescent anxiety and mental health issues to a variety of factors, while most believe that the COVID-19 epidemic exacerbated the problem. The goal is to analyze the changing rates of anxiety and depression with respect to the year/time, age, gender and ethenicity of the people living in US.

# %% [markdown]
# # Data Selected for Analysis

# %% [markdown]
# The data selected for this analysis is https://data.cdc.gov/NCHS/Indicators-of-Anxiety-or-Depression-Based-on-Repor/8pt5-q6wp. The data is freely available to use from the CDC website and has information needed to make this study relevant.

# %% [markdown]
# ### **This data is comprehensive:**
# - Groups such as: age, sex, race/ethnicity, national estimate
#     - Subgroup such as: male/female, age #, hispanic or latino, wyoming
# - Indicator such as: Symptom of depression, symptom of anxiety
# - 50 different states in the United states
# - Time period start to end
# - With disability & Without disability

# %% [markdown]
# - Rows: 9,918
# - Columns: 14
# - Each row represents: estimate of anxiety or depression

# %% [markdown]
# ### **Time range:**
# - Data issued: May 20th 2020
# - Data last updates: April 20th 2022 (as I am writing this)

# %% [markdown]
# # Unknowns and Dependencies

# %% [markdown]
# - There is a of medical terms and acronyms from the CDC dataset that I will need to look out for (Examples: Low IC, High IC, confidence interval).
# - As this is my first time doing data Analysis, I will need get ore help from my instructor/teacher assistance.
# - I have recently just made changes to my data topic to analyse as I feel that the previous topic does not really align with my passion. That being said, I will need to catch up with materials.

# %% [markdown]
# # Research Questions / Hypothesis

# %% [markdown]
# **Questions that arise from my problem statements are:**
#
# 1. How is levels of anxiety and that of depression related ?
# 2. How is anxiety and depression level related with age group ? (percentage of symptoms with the interval of 10 years).
# 3. When is the anxiety and depression level highest ? How has those levels changed with time?
# 4. What is the impact of race in the rate of change of depression and anxiety levels through the pandemic period ?
# 5. What is the impact of disability status in the rate of change of depression and anxiety levels through the pandemic period ?

# %% [markdown]
# **Hypothesis**
#
# 1. Higher level of anxiety may lead to higher level of depression. It's not necessary that both levels are highest at a same      time but one leads the other.
# 2. Younger age will have higher depression rate than older age
# 3. The higher levels of anxiety and depression will be around the peak of the Covid-19 Pandemic.
# 4. I do not think I can hypothesize this
# 5. Disabled people might have suffered greater change in levels of depression and anxiety during covid19.

# %% [markdown]
# # Background and/or Related Work

# %% [markdown]
# The emergence of the COVID-19 pandemic aggravated an already existing public mental health problem. Mental disorders were already the [global leading causes of the health-related burden](https://www.thelancet.com/journals/lancet/article/PIIS0140-6736(21)02143-7/fulltext), especially depressive and anxiety disorders. As a consequence of COVID-19, the pandemic created an environment exacerbating the determinants of poor mental health. Emotional distress, stress, irritability, anger, and mood swings are [among the symptoms of mental trauma](https://globalizationandhealth.biomedcentral.com/articles/10.1186/s12992-020-00589-w) related to the pandemic. According to the Anxiety & Depression Association of America (ADAA), [40 million American adults aged 18 and older](https://adaa.org/understanding-anxiety/facts-statistics#:~:text=GAD%2520affects%25206.8%2520million%2520adults,to%2520be%2520affected%2520as%2520men.) suffer anxiety disorders; the most common mental illness in the United States (US). Fear and grief associated with disease spread, social restrictions, and other pandemic containment measures to reduce mortality and morbidity worsen psychological wellbeing because of feelings of isolation and even loss of livelihoods and loved ones. Unsurprisingly, the percentage of individuals with anxiety or a depressive disorder symptom increased from [36.4% to 41.5%](https://www.cdc.gov/mmwr/volumes/70/wr/mm7013e2.htm#suggestedcitation) during the August 2020-to-February 2021 period. With the reality of worsening situations related to mental health, understanding the trends of anxiety and depression is crucial in guiding health and public policy formulation. As the burden of psychological disorders continues to plague the healthcare system, there is a need for better risk assessment as well as intervention and prevention.

# %% [markdown]
# # Methodology

# %% [markdown]
# **Research Question 1:**

# %% [markdown]
# To find out relation between change in anxiety levels with change in depression levels, I can seperate dataset with respect to the indicator. I will then create line plots to show change in both levels with respect to time. It will help to know if the change in anxiety and depression levels occur simultaneously or one follows the other.

# %% [markdown]
# **Research Question 2:**

# %% [markdown]
# To determine if certain age group show more or less anxiety and depression levels than others, first I will select the instances that are grouped by age as indicated in 'Group' column. Then I will create a bar chart showing average value of depression and anxiety for each age group so that it can be visually observed if some age group have significantly higher or lower levels of depression and anxiety.

# %% [markdown]
# **Research Question 3:**

# %% [markdown]
# To determine if the depression and anxiety levels increased during the peak of pandemic, I will create a time series graph of the value for different indicators.
# Moreover, I will also try to include the covid 19 data and create an overlapping time series graph for cases and compare two trends i.e. covid 19 cases and level of depression and anxiety. This will help in visually determining if the peaks and dips in two trends are coincident or not.

# %% [markdown]
# **Research Question 4:**

# %% [markdown]
# To find out the race/hispanic ethnicity with highest and lowest levels of depression and anxiety, i can use simple data manipulation techniques in python. I will first create a dataframe with instances only grouped by race/ hispanic ethnicity. Then i will apply 'loc' method in pandas to segregate data for each unique race. I will plot the values of anxiety and depression levels with respect to time for each unique group. I will make seperate plots for depression levels and anxiety levels. This will help in visually understanding the change in levels of anxiety and depression in time.

# %% [markdown]
# **Research Question 5:**

# %% [markdown]
# At first, i will select rows with value 'By Disability status' in 'Group' column. Then i will create a line plot showing value in column 'value' for each instances with respect to time. Then i can give seperate colour to the instances based on the diability status. This will help to visually analyze if instances with disability suffered greater change in levels of anxiety and depression.

# %% [markdown]
# # Using Data Analysis to answer Research Questions

# %% [markdown]
# Since my research objectives required visualizations to properly answer them and since the dataset was available in a format easily accessible with python modules, I choose to perform data analysis using python. Following are the steps of data analysis with proper implementation using python:

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Loading and Inspection

# %%
data = pd.read_csv('depression_indicators.csv')
data.head()
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup Phase  Time Period     Time Period Label  \
# 0  United States     1            1  Apr 23 - May 5, 2020
# 1  18 - 29 years     1            1  Apr 23 - May 5, 2020
# 2  30 - 39 years     1            1  Apr 23 - May 5, 2020
# 3  40 - 49 years     1            1  Apr 23 - May 5, 2020
# 4  50 - 59 years     1            1  Apr 23 - May 5, 2020
#
#   Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# 0             04/23/2020           05/05/2020   23.5    22.7     24.3
# ...

# %%
data['Group'].unique()
# Out:
# array(['National Estimate', 'By Age', 'By Sex',
#        'By Race/Hispanic ethnicity', 'By Education', 'By State',
#        'By Disability status', 'By Gender identity',
#        'By Sexual orientation'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9918 entries, 0 to 9917
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Indicator               9918 non-null   object
#  1   Group                   9918 non-null   object
#  2   State                   9918 non-null   object
#  3   Subgroup                9918 non-null   object
#  4   Phase                   9918 non-null   object
#  5   Time Period             9918 non-null   int64
#  6   Time Period Label       9918 non-null   object
#  7   Time Period Start Date  9918 non-null   object
#  8   Time Period End Date    9918 non-null   object
#  9   Value                   9540 non-null   float64
#  10  Low CI                  9540 non-null   float64
#  11  High CI                 9540 non-null   float64
#  12  Confidence Interval     9540 non-null   object
#  13  Quartile Range          6732 non-null   object
# ...

# %% [markdown]
# ### Data Preparation

# %%
data['Time Period Start Date'] = data['Time Period Start Date'].astype('datetime64')
data1 = data.set_index(['Time Period Start Date'] )

data['Time Period End Date'] = data['Time Period End Date'].astype('datetime64')
data2 = data.set_index(['Time Period End Date'] )

# %%
depression1 = data1.loc[data1['Indicator'] == 'Symptoms of Depressive Disorder']
anxiety1 = data1.loc[data1['Indicator'] == 'Symptoms of Anxiety Disorder']

# %%
depression2 = data2.loc[data2['Indicator'] == 'Symptoms of Depressive Disorder']
anxiety2 = data2.loc[data2['Indicator'] == 'Symptoms of Anxiety Disorder']

# %% [markdown]
# ### Inspecting research Question 1.

# %%
plt.figure(figsize = (10,5))
sns.lineplot(data = depression1[ 'Value'], color = 'green')
sns.lineplot(data = depression2[ 'Value'], color = 'red')
sns.lineplot(data = anxiety1['Value'], color = 'brown')
sns.lineplot(data = anxiety2['Value'], color = 'blue')
plt.legend(['Depression at Start','','Depression at End','', 'Anxiety at Start','','Anxiety at End', ''])
plt.xticks(rotation = 30)
plt.title('Anxiety and Depression Values in Time', fontsize = 20)
plt.xlabel('Date', fontsize = 15)
plt.ylabel('Levels of Anxiety or Depression', fontsize = 15)
# Out:
# Text(0, 0.5, 'Levels of Anxiety or Depression')

# %% [markdown]
# ### Inspecting research Question 2.

# %%
q2_data = data[['Indicator',
                      'Group',
                      'Subgroup',
                      'Time Period Start Date','Time Period End Date',
                      'Value']]

# %%
q2_depr = q2_data.loc[(q2_data['Group'] == 'By Age') & (q2_data['Indicator'] == 'Symptoms of Depressive Disorder')]
q2_anx = q2_data.loc[(q2_data['Group'] == 'By Age') & (q2_data['Indicator'] == 'Symptoms of Anxiety Disorder')]

# %%
depression_by_age = q2_data.groupby(['Subgroup']).mean()
anxiety_by_age = q2_anx.groupby(['Subgroup']).mean()

by_age = depression_by_age.merge(anxiety_by_age, left_index = True, right_index = True)
by_age.rename(columns = {'Value_x' : 'Depression Level', 'Value_y' : 'Anxiety Level'}, inplace = True)

by_age
# Out:
#                     Depression Level  Anxiety Level
# Subgroup
# 18 - 29 years              43.683333      43.015909
# 30 - 39 years              35.796970      36.965909
# 40 - 49 years              32.118182      33.336364
# 50 - 59 years              28.935606      29.575000
# 60 - 69 years              22.731818      22.788636
# 70 - 79 years              16.717424      16.175000
# 80 years and above         15.442424      14.711364

# %%
by_age.plot(kind = 'bar', rot = 0, figsize = (10,5))
plt.xlabel('Age Group')
plt.ylabel('Average Depression or Anxiety Level')
plt.title('Average Depression and Anxiety by Age Group')
# Out:
# Text(0.5, 1.0, 'Average Depression and Anxiety by Age Group')

# %% [markdown]
# ### Inspecting research Question 3.

# %% [markdown]
# We got the data for trend of covid 19 cases from the site: https://covid.cdc.gov/covid-data-tracker/#trends_dailycases

# %%
covid_data = pd.read_csv("covid19trend.csv")
covid_data.head()
# Out:
#            State         Date  New Cases  7-Day Moving Avg  Historic Cases
# 0  United States  May 26 2022     111994            109643           10338
# 1  United States  May 25 2022     181246            109524               0
# 2  United States  May 24 2022     129997            104478               3
# 3  United States  May 23 2022     112925            104400               0
# 4  United States  May 22 2022      44325            105364               0

# %%
covid_data.columns
# Out:
# Index(['State', 'Date', 'New Cases', '7-Day Moving Avg', 'Historic Cases'], dtype='object')

# %%
covid_data['Date'] = covid_data['Date'].astype('datetime64')
covid_data.set_index(['Date'], inplace = True)

covid_data.drop(['Historic Cases'],axis = 1,  inplace = True)

# %%
mapped = depression1[['Value']]/max(depression1['Value'])
mapped_1 = anxiety1[['Value']]/max(anxiety1['Value'])
covid_mapped = covid_data[['7-Day Moving Avg']]/max(covid_data['7-Day Moving Avg'])

# %%
plt.figure(figsize = (10,5))
sns.lineplot(data = covid_mapped['7-Day Moving Avg'] , color = 'green')
sns.lineplot(data = mapped['Value'], color = 'red')
sns.lineplot(data = mapped_1['Value'], color = 'orange')
plt.grid()
plt.legend(['Cases', 'Depression Value','', 'Anxiety Value'])
plt.ylabel('Average Covid Cases or Depression/Anxiety Value')
plt.title('Trend of Covid Cases, Depression Levels and Anxiety Levels')
# Out:
# Text(0.5, 1.0, 'Trend of Covid Cases, Depression Levels and Anxiety Levels')

# %% [markdown]
# ### Inspecting research Question 4.

# %%
depression1['Group'].unique()
# Out:
# array(['National Estimate', 'By Age', 'By Sex',
#        'By Race/Hispanic ethnicity', 'By Education', 'By State',
#        'By Disability status', 'By Gender identity',
#        'By Sexual orientation'], dtype=object)

# %%
dep_by_race = depression1.loc[depression1['Group'] == 'By Race/Hispanic ethnicity']
anx_by_race = anxiety1.loc[anxiety1['Group'] == 'By Race/Hispanic ethnicity']

# %%
races = dep_by_race['Subgroup'].unique()
colors = ['red', 'brown', 'green', 'blue', 'orange']

# %%
plt.figure(figsize = (10,5))
for race, color in zip(races, colors):
    dep = dep_by_race.loc[dep_by_race['Subgroup'] == race]
    sns.lineplot(data = dep['Value'], color = color)
plt.legend(races, loc = 0, fontsize = 'small')
plt.title('Depression trend for various races', fontsize = 15)
plt.xlabel('Time Period', fontsize = 12)
plt.ylabel('Depression Level', fontsize = 12)
# Out:
# Text(0, 0.5, 'Depression Level')

# %%
dep_bar = dep_by_race[['Subgroup','Value']].groupby(by = 'Subgroup').mean()

dep_bar.plot(kind = 'bar',
             rot = 15,
             figsize = (12,7),
             ylabel = 'Average recorded depression level')
plt.title('Average Depression Levels of Different Race', fontsize = 15)
plt.xlabel('Race/Ethnicity')
# Out:
# Text(0.5, 0, 'Race/Ethnicity')

# %%
plt.figure(figsize = (14,8))
for race, color in zip(races, colors):
    anx = anx_by_race.loc[anx_by_race['Subgroup'] == race]
    sns.lineplot(data = anx['Value'], color = color)
plt.legend(races)
plt.title('Anxiety trend for various races', fontsize = 15)
plt.xlabel('Time Period', fontsize = 12)
plt.ylabel('Anxiety Level', fontsize = 12)
# Out:
# Text(0, 0.5, 'Anxiety Level')

# %%
anx_bar = anx_by_race[['Subgroup','Value']].groupby(by = 'Subgroup').mean()

anx_bar.plot(kind = 'bar',
             rot = 15,
             figsize = (10,5),
             ylabel = 'Average recorded anxiety level')
plt.title('Average Anxiety Levels of Different Race', fontsize = 15)
plt.xlabel('Race/Ethnicity')
# Out:
# Text(0.5, 0, 'Race/Ethnicity')

# %%
dep_bar.plot(kind = 'bar',
             rot = 15,
             figsize = (12,7),
             ylabel = 'Average recorded depression level')
plt.title('Average Depression Levels of Different Race', fontsize = 15)
plt.xlabel('Race/Ethnicity')
# Out:
# Text(0.5, 0, 'Race/Ethnicity')

# %% [markdown]
# ### Inspecting research Question 5.

# %%
dep_by_dis = depression1.loc[depression1['Group'] == 'By Disability status']
anx_by_dis = anxiety1.loc[anxiety1['Group'] == 'By Disability status']

# %%
status = dep_by_dis['Subgroup'].unique()
colors = ['red', 'black']

# %%
for stats in status:
    print('',stats,dep_by_dis.loc[dep_by_dis['Subgroup'] == stats]['Value'].mean())
# Out:
#  With disability 50.38823529411765
#  Without disability 17.382352941176475

# %%
plt.figure(figsize = (10,5))
for stats, color in zip(status, colors):
    dep = dep_by_dis.loc[dep_by_dis['Subgroup'] == stats]
    sns.lineplot(data = dep['Value'], color = color)
plt.legend(status)
plt.title('Depression trend with respect to disability status', fontsize = 15)
plt.xlabel('Time Period', fontsize = 12)
plt.ylabel('Depression Level', fontsize = 12)
# Out:
# Text(0, 0.5, 'Depression Level')

# %%
plt.figure(figsize = (10,5))
for stats, color in zip(status, colors):
    anx = anx_by_dis.loc[anx_by_dis['Subgroup'] == stats]
    sns.lineplot(data = anx['Value'], color = color)
plt.legend(status)
plt.title('Anxiety trend with respect to disability status', fontsize = 15)
plt.xlabel('Time Period', fontsize = 12)
plt.ylabel('Depression Level', fontsize = 12)
# Out:
# Text(0, 0.5, 'Depression Level')

# %%
status
# Out:
# array(['With disability', 'Without disability'], dtype=object)

# %%
dep_bar = dep_by_dis[['Subgroup','Value']].groupby(by = 'Subgroup').mean()

dep_bar.plot(kind = 'bar',
             rot = 15,
             figsize = (8,5),
             ylabel = 'Average recorded depression level')
plt.title('Average Depression Levels of Different Disability Status', fontsize = 15)
plt.xlabel('Disability Status')
# Out:
# Text(0.5, 0, 'Disability Status')

# %%
anx_bar = anx_by_dis[['Subgroup','Value']].groupby(by = 'Subgroup').mean()

anx_bar.plot(kind = 'bar',
             rot = 15,
             figsize = (5,3),
             ylabel = 'Average recorded anxiety level')
plt.title('Average Anxiety Levels of Different Disability Status', fontsize = 15)
plt.xlabel('Disability Status')
# Out:
# Text(0.5, 0, 'Disability Status')

# %% [markdown]
# # Results and Findings

# %% [markdown]
# In this section I have tried to present the results that I arrived at through the entire data analysis done above. I aim to give logical explanation to the findings from the data visualizations that I created using python. Explanations will be purely based on the hidden informations that we discovered in above analysis.

# %% [markdown]
# #### 1. Relation between anxiety and depression levels

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Above graph shows the trend of depression and anxiety levels from April,2020 to April,2022. It clearly shows that depression level recorded in a certain time period follows the same trajectory as of the anxiety levels recorded during same time. Although Anxiety and Depression are seperate indicators, the behaviour of both indicators are similar and the graph also shows that level of anxiety is correlated to level of depression and vice versa.

# %% [markdown]
# #### 2. Risk of anxiety and depression in relation to age

# %% [markdown]
# Age group is one of the crucial information in the data. On creating the bar chart for average level of depression and anxiety with respect to age intervals, the results are quite clear.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Above result shows that as the age grows, the age group (18-19) years had in average highest level of depression. Since this level is actually of symptoms, the risk of depression and anxiety is highest in the age group (18-19)years followed by (30-39)years, and then decreasing for each older age groups. As the age grows, the level of depression and anxiety symptoms reduces.

# %% [markdown]
# #### 3. Rise and fall of depression and anxiety symptoms during Covid 19 pandemic period

# %% [markdown]
# In the graph below, no. of covid cases and depression and anxiety values are scaled to same range i.e.0 to 1. This helped to directly compare the trend of depression and anxiety symptoms and covid19 cases.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After July 2020, we can see depression levels reaching peak values and sharply declining until September 2020 before again rising from October 2020. If we see the covid trend during the same time, we find out that Covid-19 Cases also did quite same. Until September 2021, rise and falls in depression and anxiety level responded and corresponded to the rise and falls in Covid-19 cases. But after September 2021, depression and anxiety trend didn't follow the Covid-19 trend. Depression and Anxiety level remained at higher levels during early stages of Covid-19.

# %% [markdown]
# #### 4. Depression and anxiety symptoms in different races

# %% [markdown]
# The line plot below shows the trend of anxiety and depression of five different races, three of them being non-hispanic and one being latino while one plot is for other races combined. Different races performed slightly differently during this time period of two years.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Among these races race recording highest levels of anxiety and depression symptoms was 'Hispanic or Latino'. Among non-hispanic races, 'Non-hispanic, Black, single race' suffered highest levels of anxiety and depression symptoms. 'Non-hispanic Asian, single race' was the race with least levels of anxiety and depression symptoms. But during August 2020, when levels of anxiety and depression symptoms of all races peaked, Asian race recorded level higher than that to White race. But in general, Asian race seem to be less prone to anxiety and depression symptoms than other races.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Above bar chart also supports that 'Non-hispanic Asian, single race' had least average levels of depression and anxiety symptoms.

# %% [markdown]
# #### 5. Anxiety, Depression and Disability

# %% [markdown]
# Relation of anxiety and depression symptoms with disability is more clear than any other factors. Results obtained below provides straightforward insights into the disablity and anxiety and depression related symptoms.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Two observations can be made from above graph and chart:
# 1. Levels of anxiety and depression symptoms in people with disability reacted to Covid-19 pandemic to a greater extent than in people without diasbility.
# 2. Average levels of anxiety and depression symptoms in people with disability is 3 times greater than in people without disability in our data.
